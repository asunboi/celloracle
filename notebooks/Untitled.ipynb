# %%
def scale_in_silico_fc(functional_fc, in_silico_fc):
    # Determine true label
    true_label = 1 if functional_fc > 1 else (0 if functional_fc < 1 else 0.5)
    
    # Initialize prediction score
    initial_prediction = 0.5
    
    # Determine scaling based on functional fold change
    if functional_fc > 1:  # Positive fold change
        scaled_prediction = initial_prediction + ((in_silico_fc-1)/(functional_fc-1)) * 0.5  # Scale positively
    elif functional_fc < 1:  # Positive fold change
        scaled_prediction = initial_prediction - ((in_silico_fc+1)/(functional_fc+1)) * 0.5  # Scale positively
    else:
        scaled_prediction = initial_prediction
        
    # Clip predictions to stay within [0, 1]
    scaled_prediction = max(0, min(1, scaled_prediction))
    
    return true_label, scaled_prediction

# Example usage
functional_fc = -2  # 2-fold increase in functional assay
in_silico_fc = -1.1  # 1-fold increase in in silico model

true_label, scaled_prediction = scale_in_silico_fc(functional_fc, in_silico_fc)

print(f"True Label: {true_label}, Scaled Prediction: {scaled_prediction}")
# Out:
# True Label: 0, Scaled Prediction: 0.44999999999999996

# %%
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import celloracle as co
import anndata as ad
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["savefig.dpi"] = 300
plt.rcParams["figure.figsize"] = [6, 4.5]

# %%
base_GRN = co.data.load_mouse_scATAC_atlas_base_GRN()

# %%
oracle.import_TF_data(TF_info_matrix=base_GRN)
# Out:
# TF dict already exists. The old TF dict data was deleted.

# %%
oracle = co.load_hdf5("jinlab/deg_grn/ctxobj.Tbr1_1.CR.peturbseq.subclass.celloracle.oracle")

# %%
oracle.adata.obs["predicted.subclass"].value_counts()
# Out:
# L6 CT CTX        3188
# CR               1324
# L6 IT CTX         877
# L5 NP CTX         876
# L5 IT CTX         651
# L5 IT TPE-ENT     645
# L5 PT CTX         525
# Sst               468
# Pvalb             415
# L2/3 IT CTX-1     406
# L2 IT ENTl        340
# L6b/CT ENT        306
# L2/3 IT CTX-2     296
# L4/5 IT CTX       252
# L6b CTX           249
# NP SUB            182
# Car3              122
# L2/3 IT ENTl       79
# L6 IT ENTl         79
# Sncg               42
# L2 IT RHP          30
# Vip                26
# Lamp5              19
# L3 IT ENT          18
# L2/3 IT PPP        12
# CT SUB              9
# Oligo               9
# NP PPP              7
# CA2                 6
# CA3                 5
# Sst Chodl           5
# Astro               1
# SMC-Peri            1
# L5 PPP              1
# Name: predicted.subclass, dtype: int64

# %%
astro_row = oracle.adata[oracle.adata.obs["predicted.subclass"] == "Astro"]
astro_row.to_df()
# Out:
#                         Gm5577      Asns  Tmem39a     Mocs3  Cpsf4    Fbxo11  \
# Ch4_TTGGAACAGCCACCTG-1     0.0  1.272515      0.0  0.414731    0.0  0.414731
#
#                         Naa25     Dgat1  Gm37401  Eml5  ...     Ntng1  Tmem91  \
# Ch4_TTGGAACAGCCACCTG-1    0.0  0.414731      0.0   0.0  ...  0.414731     0.0
#
#                          Tmem196  Vldlr  Cmklr1  Efhd1     Fabp3  Kndc1  \
# Ch4_TTGGAACAGCCACCTG-1  0.414731    0.0     0.0    0.0  2.467526    0.0
#
#                         Gabra3      Tbr1
# Ch4_TTGGAACAGCCACCTG-1     0.0  0.707014
#
# [1 rows x 3001 columns]

# %%
genes_in_scRNA = set(oracle.adata.var_names)
tf_genes_in_dict = set(oracle.TFdict.keys())
overlapping_genes = genes_in_scRNA.intersection(tf_genes_in_dict)

print(f"Number of overlapping genes: {len(overlapping_genes)}")
# Out:
# Number of overlapping genes: 2518

# %%
# Assuming your list of var names is stored in a variable called 'var_names'
var_names = oracle.adata.var_names.tolist()  # Convert to a list if it's not already

# Find duplicates
duplicates = [name for name in set(var_names) if var_names.count(name) > 1]

# Output the result
if duplicates:
    print(f"Found duplicates: {duplicates}")
else:
    print("No duplicates found.")
# Out:
# Found duplicates: ['Tbr1']

# %%
# %%time
# Calculate GRN for each population in "louvain_annot" clustering unit.
# This step may take some time.(~30 minutes)
links = oracle.get_links(cluster_name_for_GRN_unit="predicted.subclass", alpha=10,
                         verbose_level=10, test_mode=True, bagging_number=10)
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# Inferring GRN for Astro...
#   0%|          | 0/2518 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:3
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/trajectory/oracle_core.py:1502, in Oracle.get_links(self, cluster_name_for_GRN_unit, alpha, bagging_number, verbose_level, test_mode, model_method, ignore_warning, n_jobs)
#    1498     if info["n_target_genes_both_TFdict_and_scRNA-seq"] == '0 genes':
#    1499         raise ValueError("Found No overlap between TF info (base GRN) and your scRNA-seq data. Please check your data format and species.")
# -> 1502 links = get_links(oracle_object=self,
#    1503                   cluster_name_for_GRN_unit=cluster_name_for_GRN_unit,
#    1504                   alpha=alpha, bagging_number=bagging_number,
#    1505                   verbose_level=verbose_level, test_mode=test_mode,
#    1506                   model_method=model_method,
#    1507                   n_jobs=n_jobs)
#    1508 return links
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/network_analysis/network_construction.py:74, in get_links(oracle_object, cluster_name_for_GRN_unit, alpha, bagging_number, verbose_level, test_mode, model_method, n_jobs)
#      71     cluster_name_for_GRN_unit = oracle_object.cluster_column_name
#      73 # calculate GRN for each cluster
# ---> 74 linkLists = _fit_GRN_for_network_analysis(oracle_object, cluster_name_for_GRN_unit=cluster_name_for_GRN_unit,
#      75                               alpha=alpha, bagging_number=bagging_number,  verbose_level=verbose_level, test_mode=test_mode,
#      76                               model_method=model_method, n_jobs=n_jobs)
#      78 # initiate links object
#      79 links = Links(name=cluster_name_for_GRN_unit,
#      80              links_dict=linkLists)
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/network_analysis/network_construction.py:138, in _fit_GRN_for_network_analysis(oracle_object, cluster_name_for_GRN_unit, alpha, bagging_number, verbose_level, test_mode, model_method, n_jobs)
#     131 gem_std = gem_imputed_std[cells_in_the_cluster_bool]
#     134 tn_ = Net(gene_expression_matrix=gem_,
#     135              gem_standerdized=gem_std,
#     136              TFinfo_dic=oracle_object.TFdict,
#     137              verbose=False)
# --> 138 tn_.fit_All_genes(bagging_number=bagging_number,
#     139                   model_method=model_method,
#     140                   alpha=alpha,
#     141                   verbose=verbose,
#     142                   n_jobs=n_jobs)
#     145 #oracle_object.linkMat[cluster] = tn_.returnResultAs_TGxTFs("coef_abs")
#     146 tn_.updateLinkList(verbose=False)
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/network/net_core.py:312, in Net.fit_All_genes(self, bagging_number, scaling, model_method, command_line_mode, log, alpha, verbose, n_jobs)
#     295 def fit_All_genes(self, bagging_number=200, scaling=True, model_method="bagging_ridge",
#     296                   command_line_mode=False, log=None, alpha=1, verbose=True, n_jobs=-1):
#     297     """
#     298     Make ML models for all genes.
#     299     The calculation will be performed in parallel using scikit-learn bagging function.
#    (...)
#     310         n_jobs (int): Number of cpu cores for parallel calculation. -1 means using all available cores.
#     311     """
# --> 312     self.fit_genes(target_genes=self.all_genes,
#     313                    bagging_number=bagging_number,
#     314                    scaling=scaling,
#     315                    model_method=model_method,
#     316                    save_coefs=False,
#     317                    command_line_mode=command_line_mode,
#     318                    log=log,
#     319                    alpha=alpha,
#     320                    verbose=verbose,
#     321                    n_jobs=n_jobs)
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/network/net_core.py:422, in Net.fit_genes(self, target_genes, bagging_number, scaling, model_method, save_coefs, command_line_mode, log, alpha, verbose, n_jobs)
#     419     loop = genes
#     421 for target_gene in loop:
# --> 422     coefs = _get_bagging_ridge_coefs(target_gene=target_gene,
#     423                                      gem=self.gem,
#     424                                      gem_scaled=self.gem_standerdized,
#     425                                      TFdict=self.TFdict,
#     426                                      cellstate=self.cellstate,
#     427                                      bagging_number=bagging_number,
#     428                                      scaling=scaling,
#     429                                      n_jobs=n_jobs,
#     430                                      alpha=alpha,
#     431                                      solver=RIDGE_SOLVER)
#     433     if isinstance(coefs, int):
#     434         self.failed_genes.append(target_gene)
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/network/regression_models.py:141, in get_bagging_ridge_coefs(target_gene, gem, gem_scaled, TFdict, cellstate, bagging_number, scaling, n_jobs, alpha, solver)
#     138 model.fit(data, label)
#     140 # get results
# --> 141 coefs = _get_coef_matrix(model, reg_all)
#     143 # remove cellstate data from coefs
#     144 coefs = coefs[intersect(reggenes, coefs.columns.values)]
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/network/regression_models.py:156, in _get_coef_matrix(ensemble_model, feature_names)
#     153 feature_names = np.array(feature_names)
#     154 n_estimater = len(ensemble_model.estimators_features_)
#     155 coef_list = \
# --> 156     [pd.Series(ensemble_model.estimators_[i].coef_,
#     157                index=feature_names[ensemble_model.estimators_features_[i]])\
#     158      for i in range(n_estimater)]
#     160 coef_df = pd.concat(coef_list, axis=1, sort=False).transpose()
#     162 return coef_df
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/network/regression_models.py:157, in <listcomp>(.0)
#     153 feature_names = np.array(feature_names)
#     154 n_estimater = len(ensemble_model.estimators_features_)
#     155 coef_list = \
#     156     [pd.Series(ensemble_model.estimators_[i].coef_,
# --> 157                index=feature_names[ensemble_model.estimators_features_[i]])\
#     158      for i in range(n_estimater)]
#     160 coef_df = pd.concat(coef_list, axis=1, sort=False).transpose()
#     162 return coef_df
#
# IndexError: index 79 is out of bounds for axis 0 with size 79

# %%
# Out:
# input file name: /gpfs/home/asun/jinlab/ctxobj.rds
# Loading required package: SeuratObject
# Loading required package: sp
#
# Execution halted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Download dataset. You can change the code blow to use your data.
# ----> 2 adata = co.data_conversion.seurat_object_to_anndata("/gpfs/home/asun/jinlab/ctxobj.rds",
#       3                                                     delete_tmp_file=True)
#       5 raw_count_layer = adata['RNA'].layers['raw_count']
#       6 adata['RNA'].X = raw_count_layer
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/data_conversion/process_seurat_object.py:40, in seurat_object_to_anndata(file_path_seurat_object, delete_tmp_file)
#      35 # run R script to extract information and make mtx files
#      36 #os.makedirs("tmp", exist_ok=True)
#      37 command = f"Rscript {rscript_folder}/seurat_to_mtx.R {file_path_seurat_object}"
# ---> 40 exec_process(command, message=True, wait_finished=True, return_process=False)
#      42 print("making AnnData ...")
#      45 folder = "./tmp"
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/utility/utility.py:159, in exec_process(commands, message, wait_finished, return_process)
#     157 if message:
#     158     with io.open(process.stdout.fileno(), closefd=False) as stream:
# --> 159         [print(line.rstrip('\n')) for line in stream]
#     160 if wait_finished:
#     161     # プロセス終了まで待ち、結果を判定する
#     162     process.wait()
#
# File ~/miniforge3/envs/celloracle/lib/python3.10/site-packages/celloracle/utility/utility.py:159, in <listcomp>(.0)
#     157 if message:
#     158     with io.open(process.stdout.fileno(), closefd=False) as stream:
# --> 159         [print(line.rstrip('\n')) for line in stream]
#     160 if wait_finished:
#     161     # プロセス終了まで待ち、結果を判定する
#     162     process.wait()
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(f"/gpfs/home/asun/jinlab/tsv/edgeR_LRT_with_sva.Tbr1_1.CR.tsv", sep='\t')
df_sorted = df.iloc[df['logFC'].abs().argsort()]
df_sorted.set_index("Unnamed: 0")
rows_to_add = df_sorted.loc[df_sorted["Unnamed: 0"] == "Tbr1"]
DEG = df_sorted.tail(3000)
DEG = pd.concat([DEG, rows_to_add], ignore_index=True)
DEG.set_index("Unnamed: 0")
deg_list = DEG['Unnamed: 0'].unique().tolist()

# %%
deg_list
# Out:
# ['Gm5577',
#  'Asns',
#  'Tmem39a',
#  'Mocs3',
#  'Cpsf4',
#  'Fbxo11',
#  'Naa25',
#  'Dgat1',
#  'Gm37401',
#  'Eml5',
#  'Zkscan6',
#  'Arid5a',
#  'Nat10',
#  'Selenon',
#  'Kcnd3',
#  'Ankrd49',
#  'Pkig',
#  'Cadps',
#  'Ankrd6',
#  'Bscl2',
#  'Rps27rt',
#  'Lrrc24',
#  'Enah',
#  'Exosc1',
#  'Trmu',
#  'Slc6a17',
#  'Zfp322a',
#  'Tfdp1',
#  'Med16',
#  'Stradb',
#  'Mid2',
#  'Ttc9c',
#  'Hlcs',
#  'Gtpbp1',
#  'AW554918',
#  'Fam13c',
#  '0610010F05Rik',
#  'Cxxc1',
#  'Mxd1',
#  '2300009A05Rik',
#  'Glrx',
#  'Nxn',
#  'Pcyox1l',
#  'Nxph3',
#  'Vasp',
#  'Skil',
#  'Pea15a',
#  'Pkn2',
#  'Borcs5',
#  'Zfp846',
#  'Tsc22d3',
#  'Zfp422',
#  'Lratd1',
#  'Edc4',
#  'Smim27',
#  'Snap29',
#  'Slc25a51',
#  'Smim8',
#  'Socs6',
#  'Inip',
#  'Prxl2c',
#  'Hadha',
#  'Kat6b',
#  'Mrps18b',
#  'Ptgds',
#  'Avl9',
#  'Tbr1',
#  'Zfp532',
#  'Prickle2',
#  'Gpr173',
#  'Bicral',
#  'Unc13b',
#  'Lrch2',
#  'Txnrd2',
#  'Ccar2',
#  'Atp1b3',
#  'Hdac10',
#  'Tcaim',
#  'Ube2k',
#  'Kif17',
#  'Panx2',
#  'Cbx7',
#  'Eno1',
#  'Mblac2',
#  'Qrsl1',
#  'Lyrm1',
#  'Pcca',
#  'Atg3',
#  'Tpm4',
#  'A830082N09Rik',
#  'Pisd',
#  'Ado',
#  'Pdik1l',
#  'Riok2',
#  'Rrp7a',
#  'Pttg1',
#  'Grtp1',
#  '1810026B05Rik',
#  'Dnajc12',
#  'Gm12743',
#  'Med6',
#  '2900026A02Rik',
#  'Gclc',
#  'Trim26',
#  'Tatdn2',
#  'Anp32e',
#  'Hmg20b',
#  'E130311K13Rik',
#  'Zfp318',
#  'Ldah',
#  'Nav1',
#  'Egfl6',
#  'Epha5',
#  'Cnpy2',
#  'Neto1',
#  'Nipal3',
#  'Eefsec',
#  'Zfp81',
#  'Wdr82',
#  'Commd2',
#  'Tollip',
#  'Champ1',
#  'Tomm70a',
#  'Lrrc41',
#  'Gpr149',
#  'Agfg2',
#  'Exd2',
#  'Grin1os',
#  'Slc31a1',
#  'Amdhd2',
#  'Pbx4',
#  'B4galt6',
#  'Cpt2',
#  'Cptp',
#  'Fdft1',
#  'Adgra3',
#  'Tle4',
#  'Sgpp1',
#  'Pcnx2',
#  'Kin',
#  'Gm4258',
#  'Wdr44',
#  'Cars',
#  'Pcyox1',
#  'Fmn2',
#  'Wdr18',
#  'Dcaf12l1',
#  'Dennd2a',
#  'Fam120a',
#  'Ptpn11',
#  'Naa60',
#  'BC004004',
#  'Polr3e',
#  'Cnn3',
#  'D10Wsu102e',
#  'Zcchc10',
#  'Epb41l1',
#  'Urod',
#  'Med15',
#  'Pnkd',
#  'Pwp2',
#  'Klhl23',
#  'Abhd13',
#  'Med11',
#  'Btbd9',
#  'Nacc2',
#  'Slc25a28',
#  'Tlnrd1',
#  'Fam76b',
#  'Vps16',
#  'Dusp7',
#  'Tex2',
#  'Hip1r',
#  'Alg13',
#  'Dnajc1',
#  'Myl12a',
#  'Rnf114',
#  'Etfrf1',
#  'Samm50',
#  'Peak1',
#  'Stk40',
#  'Ccdc71',
#  'Fahd2a',
#  'Ogfr',
#  '2610507B11Rik',
#  'Sh2b1',
#  'Bola2',
#  'Samd1',
#  'Cept1',
#  'Rrnad1',
#  'Igip',
#  'Naa40',
#  'Tceal6',
#  'Zyg11b',
#  'Slc35a2',
#  'Sytl1',
#  'Spata1',
#  'Sin3a',
#  'Ogt',
#  'Tmem14a',
#  'Preb',
#  'Ranbp17',
#  'Mttp',
#  'Kcnq5',
#  'Flcn',
#  'Lmbrd2',
#  'Zfp995',
#  'Commd9',
#  'Nt5m',
#  'Larp7',
#  'Ppp1r3f',
#  'Samd12',
#  'Gm11175',
#  'Zfp768',
#  'Ero1l',
#  'Ddx3y',
#  'Cyp2j6',
#  'Phactr1',
#  'Wdr92',
#  'Qtrt1',
#  'Supt3',
#  'Cnot3',
#  'C730034F03Rik',
#  'Dram2',
#  'Tiam1',
#  'Arl6',
#  'Epha3',
#  'Zfp945',
#  'Hspa12a',
#  'Hnrnpm',
#  'Fitm2',
#  'Pygo1',
#  'Ctnnbl1',
#  'Eny2',
#  'Cadm1',
#  'Insyn2a',
#  'Pou2f2',
#  'Ino80b',
#  'Snrpa1',
#  'Sema4b',
#  'Gatd3a',
#  'Nkiras1',
#  'Mapk7',
#  'Hecw2',
#  'Smpd2',
#  'Ranbp2',
#  'Vwa8',
#  'Mthfr',
#  'Cdk12',
#  'Fam20a',
#  'Xpnpep1',
#  'Tfip11',
#  'Morc4',
#  'Ppfia4',
#  'Glce',
#  'Zfp385a',
#  'Tvp23b',
#  'Hspa14',
#  'Aox4',
#  'D5Ertd579e',
#  'Ddit3',
#  'Cdadc1',
#  'Mcm3ap',
#  'Sik2',
#  'Acad9',
#  'Tsc22d4',
#  'Commd3',
#  'Pcdhac2',
#  'Stk26',
#  'Slc35f5',
#  'Xpo6',
#  'Dcaf15',
#  'P2rx4',
#  'Zscan2',
#  'Ttc28',
#  'Nup35',
#  'Fbxo32',
#  'Gm14325',
#  'Mecr',
#  'Fry',
#  'Nmnat2',
#  'Gpatch11',
#  'Chrac1',
#  'Bbs2',
#  'Nnat',
#  'Timm8a1',
#  'Cbfa2t2',
#  'Adck1',
#  'Pgpep1',
#  'Rpl21',
#  'Ddhd2',
#  'Lrrc8d',
#  'Fam50a',
#  'Taf11',
#  'Fam89b',
#  'Grid2ip',
#  'Eral1',
#  'Dgkz',
#  'Mir124-2hg',
#  'Sema4d',
#  'Tbc1d13',
#  'Zfp770',
#  'Dcaf13',
#  'Wdr34',
#  '2610035D17Rik',
#  'Srbd1',
#  'Nifk',
#  'Arhgef18',
#  'Arl6ip6',
#  'Prkcb',
#  'Foxn3',
#  'Agap1',
#  'Slc35b3',
#  'Pafah2',
#  'Kri1',
#  'Tbl1xr1',
#  'Khsrp',
#  'Cntn3',
#  'Dmxl1',
#  'Ykt6',
#  'Plk2',
#  'Zfp426',
#  'Mettl3',
#  'Asap2',
#  'Oxr1',
#  'Gm26672',
#  'Ercc5',
#  'S100pbp',
#  'Poldip3',
#  'AW209491',
#  'Taf6l',
#  'Rap1gds1',
#  'Slc25a22',
#  'Tbrg4',
#  'Trnt1',
#  'Fam241b',
#  'Acvr2b',
#  'Ipo11',
#  'Ssh2',
#  'Nkapd1',
#  'Khk',
#  'Pdcl',
#  'Kat8',
#  'Rc3h1',
#  'Adap1',
#  'Znhit6',
#  'Ddx49',
#  'Psme3',
#  'Kat14',
#  'Ctdspl',
#  'Crtap',
#  'Tbc1d9',
#  'Pts',
#  'Cyp46a1',
#  'Pa2g4',
#  'Farp2',
#  'Cryl1',
#  'Stk19',
#  'Abcb1b',
#  'Pkd2',
#  'Phf6',
#  'Cacng2',
#  'Slc5a6',
#  'Nyap2',
#  'Tubgcp5',
#  'Ctdsp2',
#  'Hipk1',
#  'Tmem19',
#  'Sesn1',
#  'Arhgef11',
#  'Acsl4',
#  'Por',
#  'Cep295',
#  'Gfm1',
#  'Dcx',
#  'Slc17a5',
#  'Rnf19b',
#  'Dock9',
#  'Eif4e3',
#  'Pdcl3',
#  'Agl',
#  'Spata5',
#  'Slc4a8',
#  'Wasf3',
#  'Kbtbd3',
#  'Ddx41',
#  'Nebl',
#  'Gnpda1',
#  'Banp',
#  'Golim4',
#  'Clcc1',
#  'Pigb',
#  'Hdac11',
#  'Atp2b2',
#  'Sox9',
#  'Traf3ip2',
#  'Bcar3',
#  'Wars2',
#  'Megf9',
#  'Dennd6a',
#  'Spsb3',
#  'Slc22a23',
#  'Akr1e1',
#  'Prss36',
#  'Catsper2',
#  'Cand1',
#  'Gm5914',
#  '9330159F19Rik',
#  'Ilvbl',
#  'Foxo3',
#  'Tmem263',
#  'Haus1',
#  'Mrpl35',
#  'Med22',
#  'Galk2',
#  'Dop1a',
#  'Cxcr4',
#  'Rps27',
#  'Ppp1r3e',
#  'Tspan9',
#  'Gm15564',
#  'Ppp1r9b',
#  'Ccnf',
#  'Slc36a1',
#  'Ppp6r2',
#  'Blzf1',
#  'Ankrd26',
#  'Eml4',
#  'Spg20',
#  'Actl6a',
#  'Arhgef28',
#  'Letm2',
#  'Katna1',
#  'Cpne3',
#  'Map3k1',
#  'Trmt13',
#  'Hira',
#  'Tafa2',
#  'Nipal2',
#  'Prps1',
#  'Mtfmt',
#  'Sept6',
#  'Fgd1',
#  'Sppl2a',
#  'Rnf185',
#  'Ttll12',
#  'Bmt2',
#  'Btg1',
#  'Tstd2',
#  'Nudt11',
#  'Syne2',
#  'Echs1',
#  'Lss',
#  'Npb',
#  'Heca',
#  'Tmem63c',
#  'Mbd5',
#  'Cib2',
#  'Ccng1',
#  'Iqgap2',
#  'Gm27000',
#  'Gprin3',
#  'Nat9',
#  'Mfsd6',
#  'Krcc1',
#  'Sfxn4',
#  'C2cd5',
#  'Coq9',
#  'Cdk10',
#  'Tspyl5',
#  'Abcd4',
#  'Nrip3',
#  'Arhgef17',
#  'Hacd3',
#  'Csmd1',
#  'Ralgds',
#  'Parn',
#  'Ssr1',
#  'Xxylt1',
#  'Cr1l',
#  'Lrch3',
#  'Pank1',
#  'Kctd2',
#  'Prpf18',
#  'Rbm48',
#  'Lasp1',
#  'Cd2ap',
#  'Agbl5',
#  '5330417C22Rik',
#  'Cherp',
#  'Srcap',
#  'Adam9',
#  'Chka',
#  'Maneal',
#  'Radil',
#  'Mbd6',
#  'Ppp1r10',
#  'Ppt1',
#  'Ppp2r3c',
#  'Plpp5',
#  'Pip4k2a',
#  'Tank',
#  'Ganab',
#  'Ptp4a3',
#  'Fibcd1',
#  'Aatf',
#  'Acsl6',
#  'Ppp1r7',
#  'Ski',
#  'Rnf6',
#  'Usp36',
#  'Tma16',
#  'C2cd2',
#  'Prrt1',
#  'Sart3',
#  'Cep85',
#  'Sort1',
#  'Cnp',
#  'Chst10',
#  'Rasa3',
#  'Sppl2b',
#  'Aen',
#  'Plpp1',
#  'Cacng4',
#  'Pogz',
#  'Slc35e2',
#  'Cgrrf1',
#  'Syt7',
#  'Tram2',
#  'Armh4',
#  'Chsy3',
#  'Arid3b',
#  'Vmn2r63',
#  'Ahcyl2',
#  'Fastkd2',
#  'Snhg16',
#  'Zfp105',
#  'Rnf8',
#  'Spats2',
#  'Herpud2',
#  'Wdr77',
#  'Mmd',
#  'Scnm1',
#  'Fam57a',
#  'Fam71e1',
#  'Rbm11',
#  'Lrrc3',
#  'Prpsap2',
#  'Stoml1',
#  'Gal3st3',
#  'Abca3',
#  '1700012D14Rik',
#  'Bag2',
#  'Sp3',
#  'Tmem47',
#  'Sh3d19',
#  'Alkbh8',
#  'Ublcp1',
#  'Ccdc130',
#  'Coq8b',
#  'Pex19',
#  'Zfp35',
#  'Naaladl2',
#  'Vps53',
#  'Efna2',
#  'Cyp20a1',
#  'Rimklb',
#  'Natd1',
#  'Nmnat1',
#  '2310001H17Rik',
#  'Gmpr',
#  'C030006K11Rik',
#  'Iffo1',
#  'Zfp956',
#  'Fen1',
#  'Zzef1',
#  'Pitrm1',
#  'Thoc1',
#  'Casd1',
#  'Nectin1',
#  'Sft2d3',
#  'Zfp575',
#  'Gpr75',
#  'Nr2f1',
#  'Sec61b',
#  'Ramp2',
#  'Abcb10',
#  'Brsk1',
#  'Gm9967',
#  'Sec61a2',
#  'Mamld1',
#  'Tbc1d19',
#  'Mpp3',
#  'Ppp2r3a',
#  'Pias2',
#  'Slc4a7',
#  'Tmem33',
#  'Bcl9l',
#  'Tubgcp4',
#  'Garnl3',
#  'Acy1',
#  '4833420G17Rik',
#  'Man2c1os',
#  'Plekhm3',
#  'Lrig3',
#  'Tasp1',
#  'Jph1',
#  'Psmg3',
#  'Scn2a',
#  'Setd3',
#  'Ube4b',
#  'Slitrk5',
#  'Xpo5',
#  'Nit1',
#  'Ugcg',
#  'Ptpn2',
#  'Tmem38b',
#  'Baz2a',
#  'Gtf2e2',
#  'Ammecr1',
#  'Colgalt1',
#  'Abca7',
#  'Lmbr1l',
#  'Slc30a7',
#  'Pgm2',
#  'Eaf2',
#  'Pdcd4',
#  'Gne',
#  'Bcs1l',
#  'Actr8',
#  'Mynn',
#  'Zmym2',
#  'Sema6b',
#  'Il6st',
#  'Ift140',
#  'Bop1',
#  'Camk2n1',
#  'Smc5',
#  'Wwp2',
#  'Negr1',
#  'Igsf3',
#  'Zfp335',
#  'Glul',
#  'Iqcc',
#  'Gm47512',
#  'Tspan6',
#  'Rai1',
#  'Plgrkt',
#  'Dpy19l4',
#  'Ptcd1',
#  'Agbl4',
#  'Lgals8',
#  'Stxbp5l',
#  'Xpo7',
#  'Glb1',
#  'Nr4a1',
#  'Hey1',
#  'Zbtb44',
#  'Cwc27',
#  'Pim3',
#  'Ctr9',
#  'Galc',
#  'Sh2d3c',
#  'Rsrc1',
#  'Maml2',
#  'Seh1l',
#  'Setd6',
#  'D6Wsu163e',
#  'Ptpn9',
#  'Tpst1',
#  'Snhg1',
#  'Zfp30',
#  'Pds5b',
#  'Lmo4',
#  'Nf2',
#  'Ier5',
#  'Smpd4',
#  'Klf8',
#  'Bzw2',
#  'Pcnx4',
#  'Caskin1',
#  '2900093K20Rik',
#  'Nkd2',
#  'Got1',
#  '4931428F04Rik',
#  '4732471J01Rik',
#  '2010315B03Rik',
#  'Slc44a2',
#  'Tbccd1',
#  'Mbtps1',
#  'Tmem138',
#  'Mtpap',
#  'Shank2',
#  'Grhpr',
#  'Gtf2h4',
#  'Ick',
#  'Cdk5r2',
#  'Pigu',
#  'Arhgap39',
#  'Il17d',
#  'Dclk2',
#  'Actr6',
#  'Rabggta',
#  'Calcoco1',
#  'Snx5',
#  'Prdm5',
#  'Gemin2',
#  'Usp30',
#  'Bhlhe22',
#  'Mmgt2',
#  'Dzip1',
#  'Zfp36',
#  'Trmt10a',
#  'Thada',
#  'Nrbp2',
#  'Dhdds',
#  'Mex3c',
#  'Lins1',
#  'Firre',
#  'Mgst3',
#  'Ssx2ip',
#  'Klhdc10',
#  'Fndc3a',
#  'Npc2',
#  '4931406P16Rik',
#  'Ercc3',
#  'Ltv1',
#  'Pamr1',
#  'Rnf2',
#  'Dhrs13',
#  'Pou6f1',
#  'Slc7a14',
#  'Mapk1ip1',
#  'Anapc13',
#  'Dpagt1',
#  'Heatr5a',
#  'Rsph9',
#  'Hpca',
#  'Med4',
#  'Gm20721',
#  'Snd1',
#  'Sct',
#  'Gpr146',
#  'Zbtb6',
#  'Ippk',
#  'Pik3c2a',
#  'Mrs2',
#  'Babam1',
#  'P2rx5',
#  'Zfp330',
#  'Aida',
#  'Nudt14',
#  'Zfp46',
#  'Fam217b',
#  'Tshz1',
#  'Cluh',
#  'Zbtb25',
#  'Hacd1',
#  'Slc35b4',
#  'Armcx6',
#  'Nek6',
#  'Myo18a',
#  'Sf3a3',
#  'Kcnn1',
#  'Acad11',
#  'Dnajb1',
#  'Esyt2',
#  '2310022A10Rik',
#  'Amotl1',
#  'Bcl2l13',
#  'Mtmr7',
#  'Stk24',
#  'Ubr7',
#  'Grpel2',
#  'Dr1',
#  'Clvs1',
#  'Inpp5k',
#  'Panx1',
#  'Nuak1',
#  'Ell',
#  'Fahd1',
#  'Mpp2',
#  'Dusp19',
#  '2610001J05Rik',
#  'Cdk2ap1',
#  'Gm47283',
#  'Zfp606',
#  'Zfp94',
#  'Pcnx3',
#  'Lca5',
#  'Lpp',
#  'Tbcd',
#  'Wnt7b',
#  'Wdr1',
#  'Atpaf1',
#  'Zdhhc24',
#  'Zdhhc18',
#  'Ppp4r1',
#  'Slc35c2',
#  'Zfp869',
#  'Rabgef1',
#  'Shisa7',
#  'Dner',
#  'Vgf',
#  'Zfp949',
#  'Ccdc61',
#  'Grid1',
#  'Ro60',
#  'Psme4',
#  'Vps72',
#  'Tram1',
#  'Fntb',
#  'Tafa1',
#  'Hexim1',
#  '1700066M21Rik',
#  'Zxdb',
#  'Naa35',
#  'Virma',
#  'Cipc',
#  'Reep1',
#  'Cavin3',
#  'Dcps',
#  'Gm8066',
#  'Pcolce2',
#  'Upp2',
#  'Ston2',
#  'Cplx1',
#  'Pnpla3',
#  'Pfkfb2',
#  'Cep63',
#  'Odf2',
#  'Rragb',
#  'Gem',
#  'Kdm1b',
#  'Tspan5',
#  'Ramac',
#  'Lin37',
#  'Tmem179b',
#  'Zfp157',
#  'Irak1bp1',
#  'Nfs1',
#  'Gm42984',
#  'Tapbp',
#  'Sirt7',
#  'Trpv2',
#  'Wdr13',
#  'Pag1',
#  'Rab2b',
#  'D430041D05Rik',
#  'Clstn3',
#  'Pnmal1',
#  'Plat',
#  'Ints6',
#  'Jcad',
#  'Kcnd2',
#  'Sun2',
#  'Lekr1',
#  'Nr1d2',
#  'Rras',
#  'Rspo1',
#  'Pex2',
#  'Rbfox3',
#  'Scyl1',
#  'Magohb',
#  'Ccdc124',
#  'Klhl20',
#  'Tchh',
#  'Nip7',
#  'Cog6',
#  'Ccdc22',
#  'Dock1',
#  'Itfg2',
#  'Pik3r1',
#  'Acap3',
#  'Ddx55',
#  'Gpatch2l',
#  'Uba3',
#  'Klf16',
#  'Sv2b',
#  'Nipsnap3b',
#  'Cds1',
#  'Mrps27',
#  'Pot1a',
#  'Usp24',
#  'Tmem109',
#  'Cetn2',
#  'Utp3',
#  'Rnf25',
#  'Snx11',
#  'Pik3r4',
#  'Secisbp2l',
#  'Qsox1',
#  'Efcab2',
#  'Nup153',
#  'Safb2',
#  'Bud23',
#  'Zfp160',
#  'Lix1l',
#  'Vps26a',
#  'Rhobtb2',
#  'Znfx1',
#  'Celsr2',
#  'Ifnar2',
#  'Fam207a',
#  'Fbxo4',
#  'Fam98c',
#  'Zfp384',
#  'A830082K12Rik',
#  '9630028H03Rik',
#  'Gm28376',
#  'Asah1',
#  'Szt2',
#  'Nsmaf',
#  'Ppcdc',
#  'Rictor',
#  'Utp18',
#  'Ipmk',
#  'B4galt7',
#  'Tmem106c',
#  'Sirt1',
#  'Pcdhgc3',
#  'Coro2b',
#  'Rps6ka2',
#  'Fam160b1',
#  'Jakmip3',
#  'Klhl13',
#  'Dolk',
#  'Zyx',
#  'Grm7',
#  'Rhobtb3',
#  'Bbs7',
#  'Tln2',
#  'Tmsb15b2',
#  'Gorab',
#  'Acot8',
#  'Bcas3',
#  'Ccdc32',
#  'Ncoa3',
#  'Alg10b',
#  'Taf9b',
#  'Patz1',
#  'AI480526',
#  'Dlgap2',
#  'Bdnf',
#  'Dstyk',
#  'Vps26c',
#  'Ankle2',
#  'Prr18',
#  'Gm15706',
#  'Kank1',
#  'Slc45a4',
#  'Map3k4',
#  'Smarca1',
#  'Thap2',
#  'Tor1aip1',
#  'Ptn',
#  'Pgrmc2',
#  'Mnat1',
#  'Nckipsd',
#  '3830406C13Rik',
#  'Camk1d',
#  'Adal',
#  '2610020C07Rik',
#  'Rbm15b',
#  'Hmgn2',
#  'Cpne8',
#  'Lclat1',
#  'Zfyve26',
#  'Kctd17',
#  'Eif2d',
#  '4632427E13Rik',
#  'Cdc7',
#  'Naa16',
#  'Tmem219',
#  'Cnpy3',
#  'Wdpcp',
#  'Dvl2',
#  'Snhg12',
#  'Rras2',
#  'Spata2',
#  'Nxph4',
#  'Rnh1',
#  'Cndp2',
#  'Tmem169',
#  'Aard',
#  'Chek2',
#  'Eps15',
#  'St3gal2',
#  'Cebpg',
#  'Tk2',
#  '4930578M01Rik',
#  'Prkab1',
#  'Carmil1',
#  'Mcm4',
#  'Gm26691',
#  'Pde1a',
#  'Abhd6',
#  'Atp1b1',
#  'Git2',
#  'D230025D16Rik',
#  ...]
